# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data = pd.read_csv(r"C:\Users\deepanshu\Downloads\house_price_predict.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.401822e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.673622e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# # Data Visualization

# %%
data['bedrooms'].value_counts().plot(kind='bar',color='green')
plt.title('Number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
data['bedrooms'].value_counts()
# Out:
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 33       1
# 11       1
# Name: bedrooms, dtype: int64

# %%
plt.scatter(data.price, data.sqft_living,c='red')
plt.title('Price vs Square feet')
# Out:
# Text(0.5, 1.0, 'Price vs Square feet')

# %%
plt.figure(figsize=(10, 10))
sns.jointplot(x=data.lat.values, y=data.long.values, size=10,color='yellow')
plt.ylabel('Longitude', fontsize=12)
plt.xlabel('Latitude', fontsize=12)
plt.show()
sns.despine
# Out:
# D:\New folder\lib\site-packages\seaborn\axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
cormap = data.corr()
plt.figure(figsize=(20,15))
sns.heatmap(cormap, annot=True)
plt.show()

# %%
plt.scatter(data.price, data.long,color='purple')
plt.title('Price vs Location of the area')
# Out:
# Text(0.5, 1.0, 'Price vs Location of the area')

# %%
plt.scatter(data.price, data.lat,color='orange')
plt.title('Price vs Latitude')
# Out:
# Text(0.5, 1.0, 'Price vs Latitude')

# %%
plt.figure(figsize = (12, 6))

plt.subplot(121)
plt.title('Price Distribuition')
sns.distplot(data['price'])

plt.subplot(122)
g1 = plt.scatter(range(data.shape[0]), np.sort(data.price.values))
g1= plt.title("Price Curve Distribuition", fontsize=15)
g1 = plt.xlabel("")
g1 = plt.ylabel("Amount(US)", fontsize=12)

plt.subplots_adjust(wspace = 0.3, hspace = 0.5,top = 0.9)
plt.show()
# Out:
# D:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.scatter(data.bedrooms, data.price)
plt.title('Bedroom vs price')
plt.show()
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter((data['sqft_living']+data['sqft_basement']), data['price'])

# %%
plt.scatter(data.waterfront, data.price)
plt.title("Waterfront vs Price (0 = no waterfront)")
# Out:
# Text(0.5, 1.0, 'Waterfront vs Price (0 = no waterfront)')

# %%
plt.scatter(data.floors, data.price)
plt.title('Floor vs Price')
# Out:
# Text(0.5, 1.0, 'Floor vs Price')

# %%
plt.scatter(data.condition, data.price)
plt.title('Condition of House vs Price')
# Out:
# Text(0.5, 1.0, 'Condition of House vs Price')

# %% [markdown]
# # Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
plt.scatter(data.zipcode, data.price)
plt.title('Which is the price location by zipcode')
# Out:
# Text(0.5, 1.0, 'Which is the price location by zipcode')

# %%
reg = LinearRegression()

# %%
# labels = data['price']
# conv_dates = [1 if values == 2014 else 0 for values in data.date]
# data['date'] = conv_dates
# train = data.drop(['id', 'price'], axis=1)

x=data.drop(['id', 'price'], axis=1)
y=data['price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 2)

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([ 0.00000000e+00, -3.37804480e+04,  4.08212017e+04,  1.09544955e+02,
#         1.02595801e-01,  1.06298791e+04,  5.17399133e+05,  5.34461229e+04,
#         2.85558816e+04,  9.57881667e+04,  6.69961633e+01,  4.25487922e+01,
#        -2.58764450e+03,  2.27374071e+01, -5.84239616e+02,  6.10096601e+05,
#        -2.10346568e+05,  2.32513868e+01, -3.59357802e-01])

# %%
predictions = reg.predict(x_test)

# %%
sns.scatterplot(predictions,y_test)
plt.xlabel('Predicted Y')
plt.ylabel('Y Test')
# Out:
# D:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Y Test')

# %%
from sklearn import metrics

# %%
print('R^2:', metrics.explained_variance_score(y_test, predictions))
print('MAE:', metrics.mean_absolute_error(y_test,predictions))
print('MSE:', metrics.mean_squared_error(y_test,predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# R^2: 0.7070963726948445
# MAE: 126041.28863516184
# MSE: 40872125325.47179
# RMSE: 202168.55671808062

# %%
sns.distplot((y_test - predictions))
# Out:
# D:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [raw]
# The Accuracy of this model using Linear Regression is 70.69%

# %% [markdown]
#  # Gradient Boosting Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
est = GradientBoostingRegressor(n_estimators=400, max_depth=5, min_samples_split=2, learning_rate=0.1, loss='ls')

# %%
est.fit(x_train, y_train)
# Out:
# GradientBoostingRegressor(max_depth=5, n_estimators=400)

# %%
est.score(x_test, y_test)
# Out:
# 0.9044976847561469

# %%
prdict = est.predict(x_test)

# %%
sns.scatterplot(predictions,y_test)
plt.xlabel('Predicted Y')
plt.ylabel('Y Test')
# Out:
# D:\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Y Test')

# %%
print('R^2:', metrics.explained_variance_score(y_test, prdict))
print('MAE:', metrics.mean_absolute_error(y_test,prdict))
print('MSE:', metrics.mean_squared_error(y_test,prdict))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, prdict)))
# Out:
# R^2: 0.904504805277369
# MAE: 64913.81173166394
# MSE: 13319871259.73157
# RMSE: 115411.74662802556

# %%
sns.distplot((y_test - prdict))
# Out:
# D:\New folder\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %% [raw]
# The Accuracy of this model is 90.54% using gradient boosting regressor
